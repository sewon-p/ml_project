# %% [markdown]
# # EDA: Simulation Data
# Exploratory analysis of SUMO simulation outputs.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Load feature dataset
df = pd.read_parquet("../data/features/dataset.parquet")
print(f"Shape: {df.shape}")
df.head()
